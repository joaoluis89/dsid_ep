# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
grpc_local = pd.read_csv("./Resultados/grpc/grpc_100exec_local.csv", index_col=0)
grpc_remoto = pd.read_csv("./Resultados/grpc/grpc_100exec_remoto.csv", index_col=0)
rpyc_local = pd.read_csv("./Resultados/rpyc/rpyc_100exec_local.csv", index_col=0)
rpyc_remoto = pd.read_csv("./Resultados/rpyc/rpyc_100exec_remoto.csv", index_col=0)
grpc_remoto_externo = pd.read_csv("./Resultados/grpc/grpc_100exec_remota_externa.csv", index_col=0)
rpyc_remoto_externo = pd.read_csv("./Resultados/rpyc/rpyc_100exec_remoto_externo.csv", index_col=0)

# %%
grpc_local_trans = grpc_local.T
grpc_remoto_trans = grpc_remoto.T
rpyc_local_trans = rpyc_local.T
rpyc_remoto_trans = rpyc_remoto.T
grpc_remoto_externo_trans = grpc_remoto_externo.T
rpyc_remoto_externo_trans = rpyc_remoto_externo.T

# %%
def createPlot(data, title, x_label, y_label, typeOfPlot, hue=None, x=None, y=None, palette=None, path=None, showfliers=False):
    if (typeOfPlot == "boxplot"):
        ax = sns.boxplot(data=data, hue=hue, showfliers=showfliers, x=x , y=y, palette=palette)
    elif (typeOfPlot == "swarmplot"):
        ax = sns.swarmplot(data=data, hue=hue, x=x , y=y, palette=palette)
    elif (typeOfPlot == "barplot"):
        ax = sns.barplot(data=data, hue=hue, x=x , y=y, palette=palette)
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    if (path != None):
        fig = ax.get_figure()
        fig.savefig(path)

# %%
createPlot(grpc_local_trans, "GRPC - Execução Local", "Tipo de chamada", "Tempo", "boxplot", path="./Resultados/plots/grpc_execução_local")

# %%
grpc_local_trans.describe()
# Out:
#          voidCall    longCall  eightLongCall  stringCall  complexCall
# count  100.000000  100.000000     100.000000  100.000000   100.000000
# mean     0.001262    0.000920       0.000984    0.000899     0.001067
# std      0.000525    0.000148       0.000151    0.000126     0.000157
# min      0.000863    0.000639       0.000663    0.000649     0.000720
# 25%      0.001108    0.000825       0.000885    0.000822     0.000978
# 50%      0.001224    0.000927       0.000976    0.000891     0.001070
# 75%      0.001298    0.000992       0.001067    0.000973     0.001176
# max      0.006175    0.001643       0.001355    0.001250     0.001514

# %%
createPlot(grpc_remoto_trans, "GRPC - Execução Remota Interna", "Tipo de chamada", "Tempo", "boxplot", path="./Resultados/plots/grpc_execução_remota_interna")

# %%
grpc_remoto_trans.describe()
# Out:
#          voidCall    longCall  eightLongCall  stringCall  complexCall
# count  100.000000  100.000000     100.000000  100.000000   100.000000
# mean     0.005206    0.005415       0.006119    0.004553     0.005150
# std      0.003208    0.003413       0.007703    0.001717     0.002671
# min      0.002445    0.002554       0.002696    0.002635     0.002792
# 25%      0.003572    0.003549       0.003819    0.003661     0.003876
# 50%      0.003969    0.004005       0.004397    0.004063     0.004485
# 75%      0.005224    0.005651       0.005315    0.004535     0.005279
# max      0.020854    0.022402       0.074517    0.013637     0.026478

# %%
createPlot(grpc_remoto_externo_trans, "GRPC - Execução Remota Externa", "Tipo de chamada", "Tempo", "boxplot", path="./Resultados/plots/grpc_execução_remota_externa", showfliers=False)

# %%
grpc_remoto_externo_trans.describe()
# Out:
#          voidCall    longCall  eightLongCall  stringCall  complexCall
# count  100.000000  100.000000     100.000000  100.000000   100.000000
# mean     0.133606    0.130333       0.130348    0.131669     0.131697
# std      0.017571    0.002039       0.002194    0.009042     0.007071
# min      0.128087    0.128111       0.128002    0.128110     0.128201
# 25%      0.129045    0.128940       0.129183    0.128727     0.129403
# 50%      0.129768    0.129599       0.129813    0.129493     0.130146
# 75%      0.130888    0.131129       0.130918    0.130533     0.131402
# max      0.284858    0.140178       0.147113    0.184545     0.191737

# %%
createPlot(rpyc_local_trans, "RPYC - Execução Local", "Tipo de chamada", "Tempo", "boxplot", path="./Resultados/plots/rpyc_execução_local")

# %%
rpyc_local_trans.describe()
# Out:
#          voidCall    longCall  eightLongCall  stringCall  complexCall
# count  100.000000  100.000000     100.000000  100.000000   100.000000
# mean     0.000684    0.000687       0.000783    0.000751     0.000743
# std      0.000320    0.000146       0.000169    0.000167     0.000163
# min      0.000496    0.000533       0.000608    0.000581     0.000582
# 25%      0.000522    0.000554       0.000631    0.000609     0.000601
# 50%      0.000665    0.000696       0.000761    0.000740     0.000749
# 75%      0.000701    0.000730       0.000855    0.000817     0.000793
# max      0.003488    0.001162       0.001355    0.001346     0.001274

# %%
createPlot(rpyc_remoto_trans, "RPYC - Execução Remota", "Tipo de chamada", "Tempo", "boxplot", path="./Resultados/plots/rpyc_execução_remota_interna")

# %%
rpyc_remoto_trans.describe()
# Out:
#          voidCall    longCall  eightLongCall  stringCall  complexCall
# count  100.000000  100.000000     100.000000  100.000000   100.000000
# mean     0.023975    0.009297       0.009834    0.009811     0.009623
# std      0.144611    0.003355       0.002865    0.003653     0.003883
# min      0.006198    0.006672       0.006389    0.007012     0.006325
# 25%      0.007308    0.007739       0.008061    0.007771     0.007733
# 50%      0.008184    0.008180       0.008767    0.008443     0.008347
# 75%      0.009436    0.009452       0.010293    0.010567     0.009648
# max      1.454077    0.035056       0.022746    0.033547     0.031543

# %%
createPlot(rpyc_remoto_externo_trans , "RPYC - Execução Remota Externa", "Tipo de chamada", "Tempo", "boxplot", path="./Resultados/plots/rpyc_execução_remota_externa")

# %%
rpyc_remoto_externo_trans.describe()
# Out:
#          voidCall    longCall  eightLongCall  stringCall  complexCall
# count  100.000000  100.000000     100.000000  100.000000   100.000000
# mean     0.394907    0.393466       0.396315    0.526196     0.393386
# std      0.017513    0.010693       0.037210    0.039179     0.010412
# min      0.383329    0.382592       0.383013    0.509697     0.382407
# 25%      0.385570    0.385732       0.385398    0.513336     0.386161
# 50%      0.390592    0.390278       0.388470    0.520523     0.389458
# 75%      0.397752    0.396316       0.396983    0.528507     0.397757
# max      0.525766    0.440318       0.743960    0.898588     0.447801

# %%
grpc_local_trans = grpc_local_trans.assign(MeioRpc="Local")
grpc_remoto_trans = grpc_remoto_trans.assign(MeioRpc="Remoto")
rpyc_local_trans = rpyc_local_trans.assign(MeioRpc="Local")
rpyc_remoto_trans = rpyc_remoto_trans.assign(MeioRpc="Remoto")
grpc_remoto_externo_trans = grpc_remoto_externo_trans.assign(MeioRpc="RemotoExterno")
rpyc_remoto_externo_trans = rpyc_remoto_externo_trans.assign(MeioRpc="RemotoExterno")

# %%
grpc_local_remoto = pd.concat([grpc_local_trans, grpc_remoto_trans])
grpc_local_remoto = pd.melt(grpc_local_remoto, id_vars="MeioRpc", value_vars=["voidCall", "longCall", "eightLongCall", "stringCall", "complexCall"])

# %%
rpyc_local_remoto = pd.concat([rpyc_local_trans, rpyc_remoto_trans])
rpyc_local_remoto = pd.melt(rpyc_local_remoto, id_vars="MeioRpc", value_vars=["voidCall", "longCall", "eightLongCall", "stringCall", "complexCall"])

# %%
grpc_local_remoto.head()
# Out:
#   MeioRpc  variable     value
# 0   Local  voidCall  0.006175
# 1   Local  voidCall  0.001207
# 2   Local  voidCall  0.001038
# 3   Local  voidCall  0.000985
# 4   Local  voidCall  0.001231

# %%
#sns.boxplot(x="variable", y="value", hue="MeioRpc",data=grpc_local_remoto, showfliers=False)
createPlot(grpc_local_remoto, "GRPC - Comparação entre execuções local e remota", "Tipo de chamada", "Tempo", "boxplot", hue="MeioRpc", x="variable", y="value", path="./Resultados/plots/grpc_execução_local_remotaInterna")

# %%
createPlot(rpyc_local_remoto, "RPYC - Comparação entre execuções local e remota", "Tipo de chamada", "Tempo", "boxplot", hue="MeioRpc", x="variable", y="value", path="./Resultados/plots/rpyc_execução_local_remotaInterna")

# %%
grpc_local_trans = grpc_local_trans.assign(Programa="Grpc")
grpc_remoto_trans = grpc_remoto_trans.assign(Programa="Grpc")
rpyc_local_trans = rpyc_local_trans.assign(Programa="Rpyc")
rpyc_remoto_trans = rpyc_remoto_trans.assign(Programa="Rpyc")
grpc_remoto_externo_trans= grpc_remoto_externo_trans.assign(Programa="Grpc")
rpyc_remoto_externo_trans= rpyc_remoto_externo_trans.assign(Programa="Rpyc")

# %%
grpc_rpyc_local = pd.concat([grpc_local_trans, rpyc_local_trans])
grpc_rpyc_local = pd.melt(grpc_rpyc_local, id_vars="Programa", value_vars=["voidCall", "longCall", "eightLongCall", "stringCall", "complexCall"])

# %%
createPlot(grpc_rpyc_local, "GRPC, RPYC - comparação de execuções locais", x_label="Tipo de chamada", y_label="Tempo", typeOfPlot="boxplot", hue="Programa", x="variable", y="value", palette="Accent", path="./Resultados/plots/grpc_rpyc_execução_local")

# %%
grpc_rpyc_remoto = pd.concat([grpc_remoto_trans, rpyc_remoto_trans])
grpc_rpyc_remoto = pd.melt(grpc_rpyc_remoto, id_vars="Programa", value_vars=["voidCall", "longCall", "eightLongCall", "stringCall", "complexCall"])

# %%
createPlot(grpc_rpyc_remoto, "GRPC, RPYC - comparação de execuções remotas", x_label="Tipo de chamada", y_label="Tempo", typeOfPlot="boxplot", hue="Programa", x="variable", y="value", palette="Accent", path="./Resultados/plots/grpc_rpyc_execução_remotaInterna")

# %%
grpc_remotos = pd.concat([grpc_remoto_trans, grpc_remoto_externo_trans])
grpc_remotos = pd.melt(grpc_remotos, id_vars="MeioRpc", value_vars=["voidCall", "longCall", "eightLongCall", "stringCall", "complexCall"])

# %%
createPlot(grpc_remotos, "GRPC - execuções remotas", x_label="Tipo de chamada", y_label="Tempo", typeOfPlot="boxplot", hue="MeioRpc", x="variable", y="value", palette="Accent", path="./Resultados/plots/grpc_execuções_remotas", showfliers=False)

# %%
rpyc_remotos = pd.concat([rpyc_remoto_trans, rpyc_remoto_externo_trans])
rpyc_remotos = pd.melt(rpyc_remotos, id_vars="MeioRpc", value_vars=["voidCall", "longCall", "eightLongCall", "stringCall", "complexCall"])

# %%
createPlot(rpyc_remotos, "Rpyc - execuções remotas", x_label="Tipo de chamada", y_label="Tempo", typeOfPlot="boxplot", hue="MeioRpc", x="variable", y="value", palette="Accent", path="./Resultados/plots/rpyc_execuções_remotas")

# %%
grpc_rpyc_remotos = pd.concat([grpc_remoto_externo_trans, rpyc_remoto_externo_trans])
grpc_rpyc_remotos = pd.melt(grpc_rpyc_remotos, id_vars="Programa", value_vars=["voidCall", "longCall", "eightLongCall", "stringCall", "complexCall"])

# %%
createPlot(grpc_rpyc_remotos, "Grpc, Rpyc - execuções remotas externas", x_label="Tipo de chamada", y_label="Tempo", typeOfPlot="boxplot", hue="Programa", x="variable", y="value", palette="Accent", path="./Resultados/plots/grpc_rpyc_execuções_remotas")

# %%
createPlot(grpc_rpyc_remotos, "Rpyc - execuções remotas", x_label="Tipo de chamada", y_label="Tempo", typeOfPlot="swarmplot", hue="Programa", x="variable", y="value", palette="Accent", path="./Resultados/plots/swarmplot_grpc_rpyc_execuções_remotas" )

# %%
rpyc_remoto_externo_trans.describe()
# Out:
#          voidCall    longCall  eightLongCall  stringCall  complexCall
# count  100.000000  100.000000     100.000000  100.000000   100.000000
# mean     0.394907    0.393466       0.396315    0.526196     0.393386
# std      0.017513    0.010693       0.037210    0.039179     0.010412
# min      0.383329    0.382592       0.383013    0.509697     0.382407
# 25%      0.385570    0.385732       0.385398    0.513336     0.386161
# 50%      0.390592    0.390278       0.388470    0.520523     0.389458
# 75%      0.397752    0.396316       0.396983    0.528507     0.397757
# max      0.525766    0.440318       0.743960    0.898588     0.447801

# %%
createPlot(grpc_rpyc_remotos, "Rpyc - execuções remotas", x_label="Tipo de chamada", y_label="Tempo", typeOfPlot="barplot", hue="Programa", x="variable", y="value", palette="Accent", path="./Resultados/plots/barplot_grpc_rpyc_execuções_remotas" )
